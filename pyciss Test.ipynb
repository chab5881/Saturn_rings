# %%
from pyciss.ringcube import RingCube
#import numpy as np
#from matplotlib import pyplot as plt

# %%
test1 = RingCube('N1584974162')
test1.imshow()

# %%
#comments to test git

# %%
#comment #2 to test git commit
