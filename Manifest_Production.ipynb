# %%
import numpy as np
import csv
from glob import glob

rawDir = glob("/cassini_ringsdata/db/N*")  #This leaves out the one directory with W*
rawDir = np.array(rawDir)

for i in np.arange(0,rawDir.size):
    rawDir[i] = rawDir[i][22:]

print(rawDir.size)
# Out:
# 0

# %%
shortDir = glob("../pngFiles/*plot.png")  #This leaves out the one directory with W*
shortDir = np.array(shortDir)

for i in np.arange(0,shortDir.size):
    shortDir[i] = shortDir[i][12:23]

print(shortDir)
# Out:
# ['N1586623770' 'N1503242651' 'N1503242357' 'N1640503812' 'N1591676646'
#  'N1654249414' 'N1601009905' 'N1541717212' 'N1628674271' 'N1866370730'
#  'N1628683994' 'N1870702539' 'N1503242504' 'N1628679728' 'N1503243237'
#  'N1532372319' 'N1870084756' 'N1586622480' 'N1586625834' 'N1640502532'
#  'N1467344863' 'N1591675238' 'N1866370342' 'N1503242944' 'N1640503332'
#  'N1871315964' 'N1536500714' 'N1628684061' 'N1586618145' 'N1467344804'
#  'N1560311199' 'N1591064511' 'N1467344568' 'N1871322211' 'N1875229393'
#  'N1874678436' 'N1595325637' 'N1586621362' 'N1541716352' 'N1591677538'
#  'N1467345857' 'N1560310728' 'N1541717488' 'N1560311316' 'N1586619005'
#  'N1586620811' 'N1467345149' 'N1586623598' 'N1467350987' 'N1866370633'
#  'N1591682340' 'N1586619263' 'N1586618833' 'N1586624974' 'N1597807518'
#  'N1586618059' 'N1870084227' 'N1595326077' 'N1560309492' 'N1560311811'
#  'N1628682038' 'N1640502932' 'N1586617999' 'N1656998530' 'N1628681150'
# ...

# %%
with open('manifestNonError.csv','w') as file:
    for i in np.arange(shortDir.size):
        file.write(str(i+1) + ',' + shortDir[i] + '_img.png,' + shortDir[i] + '_plot.png')
        file.write('\n')

# %%
print(rawDir.size)
# Out:
# 824
